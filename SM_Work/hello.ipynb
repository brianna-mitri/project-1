# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
amazon_data = Path("../Data/Amazon Sale Report.csv")

# Read in the data. 
amazon_df = pd.read_csv(amazon_data)
amazon_df.head()
# Out:
# /var/folders/sj/ggwfmtt11796g_ymmp495yqr0000gn/T/ipykernel_12528/3314513688.py:4: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   amazon_df = pd.read_csv(amazon_data)
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# ...

# %%
amazon_df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
amazon_df.nunique().to_frame(name="Count of Unique Values")
# Out:
#                     Count of Unique Values
# index                               128975
# Order ID                            120378
# Date                                    91
# Status                                  13
# Fulfilment                               2
# Sales Channel                            2
# ship-service-level                       2
# Style                                 1377
# SKU                                   7195
# Category                                 9
# Size                                    11
# ASIN                                  7190
# Courier Status                           3
# Qty                                     10
# currency                                 1
# Amount                                1410
# ship-city                             8955
# ship-state                              69
# ship-postal-code                      9459
# ship-country                             1
# promotion-ids                         5787
# ...

# %%
#amazon.drop(['index', 'Unnamed: 22', 'fufilled-by'] inplace = True)

# %%
consumer_df = amazon_df[amazon_df["B2B"]== False]
consumer_df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
# 5     Amazon      Amazon.in          Expedited   SET264  SET264-KR-NP-XL
#
#         Category  ... currency  Amount   ship-city     ship-state  \
# ...

# %%
consumer_df["Status"].unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
consumer_df["Status"].value_counts()
# Out:
# Status
# Shipped                          77273
# Shipped - Delivered to Buyer     28520
# Cancelled                        18259
# Shipped - Returned to Seller      1944
# Shipped - Picked Up                968
# Pending                            654
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
consumer_new = consumer_df[consumer_df["Status"]!= "Shipped - Damaged"]
consumer_new["Status"].value_counts()
# Out:
# Status
# Shipped                          77273
# Shipped - Delivered to Buyer     28520
# Cancelled                        18259
# Shipped - Returned to Seller      1944
# Shipped - Picked Up                968
# Pending                            654
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Name: count, dtype: int64

# %%
consumer_df.to_csv("../output/Example.csv")
